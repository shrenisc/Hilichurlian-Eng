# %%
import pandas as pd

data = pd.read_html("http://hilichurlian-database.herokuapp.com/filter?words=&similar=&speaker=&source=&pageSize=1000")

# %%
data=data[0]
data.head()
# Out:
#               Sentence or phrase           Speaker  \
# 0                          Olah!             Venti
# 1                     mi muhe ye             Kaeya
# 2  Mi muhe mita, mita movo lata!  Hungry Hilichurl
# 3                  Mi muhe mosi!  Hungry Hilichurl
# 4        Mani mi mita movo lata!  Hungry Hilichurl
#
#                     Translation Translation source  \
# 0                        Hello!              Venti
# 1                    I love you      Kaeya / Venti
# 2  [I want (some kind of meat)]          Ella Musk
# 3                  [I'm] hungry          Ella Musk
# 4                           NaN                NaN
#
#                                              Context  \
# 0                                                NaN
# 1                                                NaN
# 2  (First interaction with the Hungry Hilichurl) ...
# 3  (First interaction with the Hungry Hilichurl) ...
# 4  Said when the Traveler goes to give the Hungry...
#
# ...

# %%
data[data["Translation"].notna()]
# Out:
#                 Sentence or phrase           Speaker  \
# 0                            Olah!             Venti
# 1                       mi muhe ye             Kaeya
# 2    Mi muhe mita, mita movo lata!  Hungry Hilichurl
# 3                    Mi muhe mosi!  Hungry Hilichurl
# 9                     Mi mito nye.  Hungry Hilichurl
# ..                             ...               ...
# 419          Celi dada, mimi nunu!         Ella Musk
# 420                       Muhe ye!         Ella Musk
# 421                       Ye dada!         Ella Musk
# 422                       Ya yika!         Ella Musk
# 423                     Nini zido!         Ella Musk
#
#                                            Translation  \
# 0                                               Hello!
# 1                                           I love you
# 2                         [I want (some kind of meat)]
# 3                                         [I'm] hungry
# ...
