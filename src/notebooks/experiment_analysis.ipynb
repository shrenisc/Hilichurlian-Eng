# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("../../logs/Experiment_1/loss_acc_data.csv")
data.head()
# Out:
#    Unnamed: 0         0         1    2    3
# 0           0  6.967158  0.021739  0.0  0.0
# 1           1  6.987407  0.000000  0.0  0.0
# 2           2  6.924404  0.000000  0.0  0.0
# 3           3  6.885168  0.000000  0.0  0.0
# 4           4  6.970944  0.000000  0.0  0.0

# %%
plt.plot(data['0'])
plt.plot(data['1'])
plt.legend(["loss","acc"])
